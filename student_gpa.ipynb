# %% [markdown]
# # Name: Zachary Barling
# # File Name: student_gpa.ipynb
# # Description: This program accepts student names and GPAs and determines
# #              whether each student qualifies for the Dean's List or Honor Roll.

# %%
while True:
    last_name = input("Enter the student's last name (or ZZZ to quit): ")
    
    if last_name == "ZZZ":
        break

    first_name = input("Enter the student's first name: ")
    gpa = float(input("Enter the student's GPA: "))

    if gpa >= 3.5:
        print(first_name, last_name, "has made the Dean's List.")

    else gpa >= 3.25:
        print(first_name, last_name, "has made the Honor Roll.")

    print()
# Out:
# Enter the student's last name (or ZZZ to quit):  Fraim
# Enter the student's first name:  James
# Enter the student's GPA:  3.1
# Enter the student's last name (or ZZZ to quit):  Bar
# Enter the student's first name:  Zach
# Enter the student's GPA:  3.5
# Zach Bar has made the Dean's List.
# Zach Bar has made the Honor Roll.
# Enter the student's last name (or ZZZ to quit):  Dane
# Enter the student's first name:  Rich
# Enter the student's GPA:  3.0
# Enter the student's last name (or ZZZ to quit):  Phillips
# Enter the student's first name:  Jess
# Enter the student's GPA:  3.32
# Jess Phillips has made the Honor Roll.
# Enter the student's last name (or ZZZ to quit):  Fraim
# Enter the student's first name:  Emma
# Enter the student's GPA:  3.26
# Emma Fraim has made the Honor Roll.
# Enter the student's last name (or ZZZ to quit):  zzz
# Enter the student's first name:  ZZZ
# Enter the student's GPA:  ZZZ
# ...

# %% [markdown]
# > # Student GPA Dean's List and Honor Roll
# > **Name:** Zachary Barling
# > **File:** student_gpa.ipynb
# > **Description:** This program accepts student names and GPAs and determines whether each student qualifies for the Dean's List or Honor Roll.
#
# **Markdown cell**
# > ## Testing
# > The program was tested using five students with different GPAs, including students who qualified for the Dean's List, Honor Roll, both, and neither.
